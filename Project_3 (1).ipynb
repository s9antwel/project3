# %% [markdown]
# # NNIA 18/19 Project 3:  Regularization and Data Augmentation

# %% [markdown]
# ## Deadline: 26. January 2019, 23:59

# %% [markdown]
# ## 1. Dropout$~$ (9 points)

# %% [markdown]
# In the following exercise you would use an already implemented **feed-forward network** using **only** Numpy. We will add here the dropout regualrization technique that you learned about in the lecture.
#
# The goal is to implement dropout for layer 2 in the provided three-layers network.

# %% [markdown]
# Before you start, here is a simple introduction about dropout. Dropout is a regualization technique that performs random dropping of neurons with a certain probability at each mini-batch in training time. Introducing such randomness or noise at training is helpful to make the network not fully dependent on the training set and therefore, it could generalize better to other unseen data.
#
# A simple dropout implementation creates a mask ($r^{(l)}_j$) for every neuron $j$ of the hidden layer $l$ by drawing from a [Bernoulli distribution](https://en.wikipedia.org/wiki/Bernoulli_distribution) with probability $p$, where $p$ is the probability of keeping neurons. You can think of it as a coin flip for each neuron with a probability $p$ to determine if that neuron will be kept or not. For more information, refer to section 7.12 in Deep Learning book.
#
# $$ r^{(l)}_j \sim Bernoulli(p) $$
# This mask is then applied to the hidden layer output ($h^{(l)}$) to obtain the regularized hidden layer activation $\hat{h}^{(l)}$
# $$ \hat{h}^{(l)} = r^{(l)} * h^{(l)}$$
# However, such an implementation requires the layer to be multiplied by the dropout coefficient $p$ at evaluation time to balance the larger number of active units during testing.
# $$ \hat{h}^{(l)} = p * h^{(l)}$$
# Such an implementation requires the code to switch between different code blocks for forward-pass evaluation during training and testing. Hence, a smoother way to implement dropout is to use ***inverted dropout*** where the mask generated at the training is multiplied by the inverse of the dropout coefficient.
# $$ r^{(l)}_j \sim Bernoulli(p) * \frac{1}{p}$$
# This scheme allows the scaling to be learned during training and hence, no switching between code blocks is required. The idea of using inverted dropout is to provide a form of normalization; when dropping out neurons during training, we are now giving the network less neurons that what it will have in the test time. So, dividing by the keep_probs is done to scale the training so that we will not need to do anything in test time.
#
# a) The following code implements a simple one-hiddien-layer neural network similar to what you have done in project 2. Update this code to implement inverted dropout for a hidden layer size of 50 neurons (sections to be updated are marked with TODO). Make sure to handle forward and backward passes and handle inference time as well (5.5 points)

# %% [markdown]
# - Load **Fashion-MNIST** dataset and normalized it.

# %%
from __future__ import division
import os
import struct
import numpy as np
import tensorflow as tf

fashion_mnist = tf.keras.datasets.fashion_mnist
(X_trainval, Y_trainval), (X_test, Y_test) = fashion_mnist.load_data()

# %%
print(X_trainval.shape)
# Out:
# (60000, 28, 28)

# %%
X_trainval = np.reshape(X_trainval, (X_trainval.shape[0],  X_trainval.shape[1] *  X_trainval.shape[2]))
print('The X_trainval has the following shape:')
print('Rows: %d, columns: %d' % (X_trainval.shape[0], X_trainval.shape[1]))
# Out:
# The X_trainval has the following shape:
# Rows: 60000, columns: 784

# %%
X_test = np.reshape(X_test, (X_test.shape[0],  X_test.shape[1] *  X_test.shape[2]))
print('The X_test has the following shape:')
print('Rows: %d, columns: %d' % (X_test.shape[0], X_test.shape[1]))
# Out:
# The X_test has the following shape:
# Rows: 10000, columns: 784

# %% [markdown]
# - Normalize the data. Subtract the mean and divide by the standard deviation.

# %%
def data_normalization(X_trainval, X_test):
    feature_means = X_trainval.mean(axis = 0)
    feature_std = np.std(X_trainval, axis = 0)
    X_trainval_normalized = (X_trainval - feature_means) / feature_std
    X_test_normalized = (X_test - feature_means) / feature_std
    return X_trainval_normalized, X_test_normalized

# %%
# The normalization should be done on X_train and X_test
# and normalized data should have the exactly same shape as the original data matrix.

X_trainval, X_test = data_normalization(X_trainval, X_test)
print(X_trainval.shape)
print(X_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
import os
import struct
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import expit


class MLP(object):
    """ Feedforward neural network / Multi-layer perceptron classifier.

    Parameters
    ------------
    n_output : int
        Number of output units, should be equal to the
        number of unique class labels.
        
    n_features : int
        Number of features (dimensions) in the target dataset.
        Should be equal to the number of columns in the X array.
        
    n_hidden : int (default: 30)
        Number of hidden units.
        
    l1 : float (default: 0.0)
        Lambda value for L1-regularization.
        No regularization if l1=0.0 (default)
        
    l2 : float (default: 0.0)
        Lambda value for L2-regularization.
        No regularization if l2=0.0 (default)
        
    epochs : int (default: 500)
        Number of passes over the training set.
        
    eta : float (default: 0.001)
        Learning rate.
        
    alpha : float (default: 0.0)
        Momentum constant.
        
    decrease_const : float (default: 0.0)
        Decrease constant. Shrinks the learning rate
        after each epoch via eta / (1 + epoch*decrease_const)
        
    shuffle : bool (default: True)
        Shuffles training data every epoch if True to prevent circles.
        
    minibatches : int (default: 1)
        Divides training data into k minibatches for efficiency.
        Normal gradient descent learning if k=1 (default).
        
    random_state : int (default: None)
        Set random state for shuffling and initializing the weights.
    
    dropout : float (default: 1.0, no dropout)
        Set the dropout coefficient (keep probability of neurons)

    Attributes
    -----------
    cost_ : list
      Sum of squared errors after each epoch.

    """

      
    def __init__(self, n_output, n_features, n_hidden=30,
                 l1=0.0, l2=0.0, epochs=50, eta=0.001,
                 alpha=0.0, decrease_const=0.0, shuffle=True,
                 minibatches=1, random_state=1, dropout = 1.0):

        self.n_output = n_output
        self.r = np.random.RandomState(random_state)
        self.n_features = n_features
        self.n_hidden = n_hidden
        self.w1, self.w2 = self._initialize_weights()
        self.l1 = l1
        self.l2 = l2
        self.epochs = epochs
        self.eta = eta
        self.alpha = alpha
        self.decrease_const = decrease_const
        self.shuffle = shuffle
        self.minibatches = minibatches
        
        # The dropout variable is the keep probability for neurons.
        # Initialize the class variable "dropout" like other variables above. Also, initialize a variable mask to None.
        # This will allow sharing dropout information during forward and backward pass of the neural networks. Note 
        # that the __init__ function has already been modified to include dropout coefficient as an argument. (0.5 points)
        
        #TODO: Implement
        
        self.dropout = dropout
        self.mask = None

    def _encode_labels(self, y, k):    
        """Encode the labels using one-hot representation

        Parameters
        ------------
        y : y represents target values.

        Returns
        -----------
        onehot array

        """
       
        onehot = np.zeros((k, y.shape[0]))
        for idx, val in enumerate(y):
            onehot[val, idx] = 1.0
        
        return onehot

    def _initialize_weights(self):
        """Initialize weights with small random numbers."""
        
        w1 = self.r.uniform(-1.0, 1.0, size=self.n_hidden*(self.n_features + 1))
        w1 = w1.reshape(self.n_hidden, self.n_features + 1)
        w2 = self.r.uniform(-1.0, 1.0, size=self.n_output*(self.n_hidden + 1))
        w2 = w2.reshape(self.n_output, self.n_hidden + 1)
        
        return w1, w2

    def _sigmoid(self, z):
        """Compute logistic function (sigmoid)

        Uses scipy.special.expit to avoid overflow
        error for very small input values z.

        """
        
        return expit(z)

    def _sigmoid_gradient(self, z):
        """Compute gradient of the logistic function"""
        
        sg = self._sigmoid(z)
        return sg * (1.0 - sg)

    def _add_bias_unit(self, X, how='column'):
        """Add bias unit (column or row of 1s) to array at index 0"""
        
        if how == 'column':
            X_new = np.ones((X.shape[0], X.shape[1] + 1))
            X_new[:, 1:] = X
        elif how == 'row':
            X_new = np.ones((X.shape[0] + 1, X.shape[1]))
            X_new[1:, :] = X
        else:
            raise AttributeError('`how` must be `column` or `row`')
        
        return X_new

    def _feedforward(self, X, w1, w2, if_train=True):
        """Compute feedforward step

        Parameters
        -----------
        X : array, shape = [n_samples, n_features]
            Input layer with original features.
        w1 : array, shape = [n_hidden_units, n_features]
            Weight matrix for input layer -> hidden layer.
        w2 : array, shape = [n_output_units, n_hidden_units]
            Weight matrix for hidden layer -> output layer.
        if_train: if this is during training

        Returns
        ----------
        a1 : array, shape = [n_samples, n_features+1]
            Input values with bias unit.
        z2 : array, shape = [n_hidden, n_samples]
            Net input of hidden layer.
        a2 : array, shape = [n_hidden+1, n_samples]
            Activation of hidden layer.
        z3 : array, shape = [n_output_units, n_samples]
            Net input of output layer.
        a3 : array, shape = [n_output_units, n_samples]
            Activation of output layer.

        """
        
        a1 = self._add_bias_unit(X, how='column')
        z2 = w1.dot(a1.T)
        a2 = self._sigmoid(z2)
        a2 = self._add_bias_unit(a2, how='row')
        
        # Implement inverted dropout using the class variables dropout and activation variable (a2) for the forward
        # pass for the second hidden layer below. To create the mask you will have to use self.r.binomial for 
        # generating the bernoulli distribution. The mask created here needs to be stored in the appropriate mask
        # variable defined in the __init__ function for further use by the backward pass.
        # Make sure to handle the inference case (2.5 points)
        
        # TODO: Implement
        
        self.mask = self.r.binomial(1, self.dropout, size=a2.shape) / self.dropout
        a2 = a2 * self.mask
        z3 = w2.dot(a2)
        a3 = self._sigmoid(z3)
        
        return a1, z2, a2, z3, a3

    def _L2_reg(self, lambda_, w1, w2):
        """Compute L2-regularization cost"""
        
        return (lambda_/2.0) * (np.sum(w1[:, 1:] ** 2) +
                                np.sum(w2[:, 1:] ** 2))

    def _L1_reg(self, lambda_, w1, w2):
        """Compute L1-regularization cost"""
        
        return (lambda_/2.0) * (np.abs(w1[:, 1:]).sum() +
                                np.abs(w2[:, 1:]).sum())

    def _get_cost(self, y_enc, output, w1, w2):
        """Compute cost function.

        Parameters
        ----------
        y_enc : array, shape = (n_labels, n_samples)
            one-hot encoded class labels.
        output : array, shape = [n_output_units, n_samples]
            Activation of the output layer (feedforward)
        w1 : array, shape = [n_hidden_units, n_features]
            Weight matrix for input layer -> hidden layer.
        w2 : array, shape = [n_output_units, n_hidden_units]
            Weight matrix for hidden layer -> output layer.

        Returns
        ---------
        cost : float
            Regularized cost.

        """
        np.seterr(divide='ignore')
        term1 = -y_enc * (np.log(output))
        term2 = (1.0 - y_enc) * np.log(1.0 - output)
        
        term1[np.isneginf(term1)] = 0
        term2[np.isneginf(term2)] = 0
        
        cost = np.sum(term1 - term2)
        L1_term = self._L1_reg(self.l1, w1, w2)
        L2_term = self._L2_reg(self.l2, w1, w2)
        cost = cost + L1_term + L2_term
        
        return (cost / y_enc.shape[1])

    def _get_gradient(self, a1, a2, a3, z2, y_enc, w1, w2):
        """ Compute gradient step using backpropagation.

        Parameters
        ------------
        a1 : array, shape = [n_samples, n_features+1]
            Input values with bias unit.
        a2 : array, shape = [n_hidden+1, n_samples]
            Activation of hidden layer.
        a3 : array, shape = [n_output_units, n_samples]
            Activation of output layer.
        z2 : array, shape = [n_hidden, n_samples]
            Net input of hidden layer.
        y_enc : array, shape = (n_labels, n_samples)
            one-hot encoded class labels.
        w1 : array, shape = [n_hidden_units, n_features]
            Weight matrix for input layer -> hidden layer.
        w2 : array, shape = [n_output_units, n_hidden_units]
            Weight matrix for hidden layer -> output layer.

        Returns
        ---------
        grad1 : array, shape = [n_hidden_units, n_features]
            Gradient of the weight matrix w1.
        grad2 : array, shape = [n_output_units, n_hidden_units]
            Gradient of the weight matrix w2.
        """
        
        # backpropagation
        sigma3 = a3 - y_enc
        z2 = self._add_bias_unit(z2, how='row')
        sigma2 = w2.T.dot(sigma3) * self._sigmoid_gradient(z2)
        
        # Implement dropout for the backward pass, use class variables for mask and dropout for this task (2.5 points)
        
        # TODO: Implement
        
        sigma2 = sigma2 * self.mask
        
        sigma2 = sigma2[1:, :]
        grad1 = sigma2.dot(a1)
        grad2 = sigma3.dot(a2.T)

        # regularize
        grad1[:, 1:] += self.l2 * w1[:, 1:]
        grad1[:, 1:] += self.l1 * np.sign(w1[:, 1:])
        grad2[:, 1:] += self.l2 * w2[:, 1:]
        grad2[:, 1:] += self.l1 * np.sign(w2[:, 1:])

        return grad1, grad2

    def predict(self, X):
        """Predict class labels

        Parameters
        -----------
        X : array, shape = [n_samples, n_features]
            Input layer with original features.

        Returns:
        ----------
        y_pred : array, shape = [n_samples]
            Predicted class labels.

        """
        if len(X.shape) != 2:
            raise AttributeError('X must be a [n_samples, n_features] array.\n'
                                 'Use X[:,None] for 1-feature classification,'
                                 '\nor X[[i]] for 1-sample classification')

        #TODO: Call the feedforward to get a1, z2, a2, z3, a3 (0.5 point)
        
        a1, z2, a2, z3, a3 = self._feedforward(X, self.w1, self.w2)
        
        y_pred = np.argmax(z3, axis=0)
        
        return y_pred

    def fit(self, X, y, print_progress=False, validation_freq=0, X_val=None, y_val=None, data_augmentation=False):
        """ Learn weights from training data.

        Parameters
        -----------
        X : array, shape = [n_samples, n_features]
            Input layer with original features.
        y : array, shape = [n_samples]
            Target class labels.
        print_progress : bool (default: False)
            Prints progress as the number of epochs
            to stderr.
        validation_freq=0, X_val=None, y_val=None: If provided, perform validation check for early stopping (Task 2)
        data_augmentation: bool (default: False)
            If true, perform data augmentation (Task 3)

        Returns:
        ----------
        self

        """
        self.cost_ = []
        train_err = []
        test_err = []
        X_data, y_data = X.copy(), y.copy()
        y_enc = self._encode_labels(y, self.n_output)

        delta_w1_prev = np.zeros(self.w1.shape)
        delta_w2_prev = np.zeros(self.w2.shape)
        
        j = 0
        val = False
        
        if X_val is not None and y_val is not None:
            val = True
        
        for i in range(self.epochs):

            # adaptive learning rate
            self.eta /= (1 + self.decrease_const*i)

            if print_progress:
                print('Training \nEpoch: %d/%d' % (i+1, self.epochs))

            if self.shuffle:
                idx = np.random.permutation(y_data.shape[0])
                X_data, y_enc = X_data[idx], y_enc[:, idx]

            mini = np.array_split(range(y_data.shape[0]), self.minibatches)
            for idx in mini:

                # feedforward
                a1, z2, a2, z3, a3 = self._feedforward(X_data[idx],
                                                       self.w1,
                                                       self.w2)
                cost = self._get_cost(y_enc=y_enc[:, idx],
                                      output=a3,
                                      w1=self.w1,
                                      w2=self.w2)
                self.cost_.append(cost)

                # compute gradient via backpropagation
                grad1, grad2 = self._get_gradient(a1=a1, a2=a2,
                                                  a3=a3, z2=z2,
                                                  y_enc=y_enc[:, idx],
                                                  w1=self.w1,
                                                  w2=self.w2)

                delta_w1, delta_w2 = self.eta * grad1, self.eta * grad2
                self.w1 -= (delta_w1 + (self.alpha * delta_w1_prev))
                self.w2 -= (delta_w2 + (self.alpha * delta_w2_prev))
                delta_w1_prev, delta_w2_prev = delta_w1, delta_w2

            j += 1

            if val and j == validation_freq:
                X_val, y_val = X_val.copy(), y_val.copy()
                y_val_enc = self._encode_labels(y_val, self.n_output)

                print('Train error %d' % (self.cost_[-1]))
                train_err.append(self.cost_[-1])
                print('vallidation')

                #compute validation error
               # if self.shuffle:
                #    idx = np.random.permutation(y_val.shape[0])
                 #   X_val, y_val_enc = X_val[idx], y_val_enc[:, idx]

               # mini = np.array_split(range(y_val.shape[0]), self.minibatches)
                #for idx in mini:

                    # feedforward
                _, _, _, _, a3 = self._feedforward(X_val,
                                                       self.w1,
                                                       self.w2)
                cost = self._get_cost(y_enc=y_val_enc,
                                      output=a3,
                                      w1=self.w1,
                                      w2=self.w2)
                test_err.append(cost)
                print('Validation %d' % (self.test_err[-1]))
                j = 0
        
        return self, train_err, test_err

# %% [markdown]
# ---
# **Points:** $0.0$ of $6$
# **Comments:** None
#
# ---

# %% [markdown]
# b) Next we are goining to plot the variation of training and test accuracies for variying keep probability values ($p$) denoted by np.arange(0.3, 1.0, 0.3). Explain your findings, how do you observe the effect of keep probability values on accuracies. (3 points)

# %%
#TODO: for each dropout value, create a class instance and call the fit function and print the training and test accuracy in percentage for each value of dropout.

#Initialize the class for each dropout value as follows:

"""
nn = MLP(n_output=10, 
             n_features=X_trainval.shape[1], 
             n_hidden=50, 
             l2=0.0, 
             l1=0.0, 
             epochs=500, 
             eta=0.001,
             alpha=0.001,
             decrease_const=0.00001,
             minibatches=50, 
             shuffle=False,
             random_state=1,
             dropout = dropout)
"""

dropout = np.arange(0.3, 1.0, 0.3)[0]
nn1 = MLP(n_output=10, 
             n_features=X_trainval.shape[1], 
             n_hidden=50, 
             l2=0.0, 
             l1=0.0, 
             epochs=500, 
             eta=0.001,
             alpha=0.001,
             decrease_const=0.00001,
             minibatches=50, 
             shuffle=False,
             random_state=1,
             dropout = dropout)

# %%
nn11, train1, test1 = nn1.fit(X_trainval, Y_trainval)
# Out:
# ghhmg
# (1200, 28, 28)
# vhjvj
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-9178355b9acb> in <module>
# ----> 1 nn11, train1, test1 = nn1.fit(X_trainval, Y_trainval)
#
# <ipython-input-35-917fde30ab2f> in fit(self, X, y, print_progress, validation_freq, X_val, y_val, data_augmentation)
#     381                 a1, z2, a2, z3, a3 = self._feedforward(X_data[idx],
#     382                                                        self.w1,
# --> 383                                                        self.w2)
#     384                 cost = self._get_cost(y_enc=y_enc[:, idx],
#     385                                       output=a3,
#
# <ipython-input-35-917fde30ab2f> in _feedforward(self, X, w1, w2, if_train)
#     180         """
#     181
# --> 182         a1 = self._add_bias_unit(X, how='column')
#     183         z2 = w1.dot(a1.T)
#     184         a2 = self._sigmoid(z2)
#
# <ipython-input-35-917fde30ab2f> in _add_bias_unit(self, X, how)
#     143         if how == 'column':
#     144             X_new = np.ones((X.shape[0], X.shape[1] + 1))
# --> 145             X_new[:, 1:] = X
#     146         elif how == 'row':
#     147             X_new = np.ones((X.shape[0] + 1, X.shape[1]))
#
# ValueError: could not broadcast input array from shape (1200,28,28) into shape (1200,28)

# %%
import matplotlib.pyplot as plt

# Plot the training error and validation error for p values

# TODO: Implement

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# **Points:** $0.0$ of $3$
# **Comments:** None
#
# ---

# %% [markdown]
# ## 2. Early Stopping$~$ (9 points)

# %% [markdown]
# For reference see Wikipedia page: https://en.wikipedia.org/wiki/Early_stopping, and also refer to section 7.8 in Deep Learning book.
#
# *Early stopping* is a form of regualrization that avoids overfitting by using the validation set error as an indication on when to stop the training before the validation set error starts increasing again.
#
# Goal: To study how increasing neurons of a neural network (model complexity) affects the Early Stopping threshold.

# %% [markdown]
# a) First, update the feedforward neural network code from Task 1 to calculate training and validation error at every 100 iterations (also known as validation frequency) of the training scheme. For this update, you will modify the fit function. The signature of the train function in task 1 include the following default values: (validation_freq=0, X_val=None, y_val=None), notice that these arguments need to be provided to calculate the validation error (of the validation set) at every 100 iterations (validation frequency).
# Overload the fit function in task 1 to perform the early stopping if these arguments are provided (for information about function overloading, refer to: https://stackabuse.com/overloading-functions-and-operators-in-python.
# The fit function should return train_err and test_err for each step in validation frequency (that are initialized as empty). (3 points)

# %% [markdown]
# ---
# **Points:** $0.0$ of $3.0$
# **Comments:** None
#
# ---

# %% [markdown]
# b) Use this code for a different number of neurons (50, 200) and plot the variation of training and validation error for every 100th iteration up to 700 iterations. Label the axes and legends appropriately in the plots.
# Use the same X_trainval, Y_trainval, X_test, Y_test from task 1.
# Use Keep probability of dropout to 1 as in default values (no dropout).
#
# **Note:** to calculate the validation error we use the test set as a proxy validation set. In general, the correct way to do that would be to keep a separate set for validation and test, the reason for that is that any hyperparameter should be selected based on the validation set, and the test set should be kept for testing the model as unseen data only. Please keep in mind that here we are doing a simplification only for the assignment purpose.
#
# (3 points)

# %%
X_trainval.shape
# Out:
# (60000, 28, 28)

# %%
#TODO: create two classes instances and fit two times with different neurons number
nn1 = MLP(n_output=10, 
             n_features=X_trainval.shape[1], 
             n_hidden=50, 
             l2=0.0, 
             l1=0.0, 
             epochs=700, 
             eta=0.001,
             alpha=0.001,
             decrease_const=0.00001,
             minibatches=50, 
             shuffle=False,
             random_state=1,
             dropout = 1)

nn1.fit(X_trainval, Y_trainval, print_progress=True, validation_freq=100, X_val=X_test, y_val=Y_test, data_augmentation=False)
# Out:
# (60000, 784)
# Training
# Epoch: 1/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 2/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 3/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 4/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 5/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 6/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 7/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 8/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 9/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 10/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 11/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 12/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 13/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 14/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 15/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 16/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 17/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 18/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 19/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 20/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 21/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 22/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 23/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 24/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 25/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 26/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 27/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 28/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 29/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 30/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 31/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 32/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 33/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 34/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 35/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 36/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 37/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 38/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 39/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 40/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 41/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 42/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 43/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 44/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 45/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 46/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 47/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 48/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 49/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 50/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 51/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 52/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 53/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 54/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 55/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 56/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 57/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 58/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 59/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 60/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 61/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 62/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 63/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 64/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 65/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 66/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 67/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 68/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 69/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 70/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 71/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 72/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# ...
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 483/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 484/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 485/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 486/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 487/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 488/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 489/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 490/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 491/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 492/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 493/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 494/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 495/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 496/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 497/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 498/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 499/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 500/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Train error 0
# vallidation
# Validation 0
# Training
# Epoch: 501/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 502/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 503/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# Training
# Epoch: 504/700
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# (60000, 784)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-481eeec48279> in <module>
#      14              dropout = 1)
#      15
# ---> 16 nn1.fit(X_trainval, Y_trainval, print_progress=True, validation_freq=100, X_val=X_test, y_val=Y_test, data_augmentation=False)
#
# <ipython-input-50-b7fdfe3f0467> in fit(self, X, y, print_progress, validation_freq, X_val, y_val, data_augmentation)
#     378                 # feedforward
#     379                 print(X_data.shape)
# --> 380                 a1, z2, a2, z3, a3 = self._feedforward(X_data[idx],
#     381                                                        self.w1,
#     382                                                        self.w2)
#
# KeyboardInterrupt:

# %%
nn2 = MLP(n_output=10, 
             n_features=X_trainval.shape[1], 
             n_hidden=200, 
             l2=0.0, 
             l1=0.0, 
             epochs=700, 
             eta=0.001,
             alpha=0.001,
             decrease_const=0.00001,
             minibatches=50, 
             shuffle=False,
             random_state=1,
             dropout = 1)

nn2.fit(X_trainval, Y_trainval, print_progress=True, validation_freq=100, X_val=X_test, y_val=Y_test, data_augmentation=False)
# Out:
# Training
# Epoch: 1/700
# Training
# Epoch: 2/700
# Training
# Epoch: 3/700
# Training
# Epoch: 4/700
# Training
# Epoch: 5/700
# Training
# Epoch: 6/700
# Training
# Epoch: 7/700
# Training
# Epoch: 8/700
# Training
# Epoch: 9/700
# Training
# Epoch: 10/700
# Training
# Epoch: 11/700
# Training
# Epoch: 12/700
# Training
# Epoch: 13/700
# Training
# Epoch: 14/700
# Training
# Epoch: 15/700
# Training
# Epoch: 16/700
# Training
# Epoch: 17/700
# Training
# Epoch: 18/700
# Training
# Epoch: 19/700
# Training
# Epoch: 20/700
# Training
# Epoch: 21/700
# Training
# Epoch: 22/700
# Training
# Epoch: 23/700
# Training
# Epoch: 24/700
# Training
# Epoch: 25/700
# Training
# Epoch: 26/700
# Training
# Epoch: 27/700
# Training
# Epoch: 28/700
# Training
# Epoch: 29/700
# Training
# Epoch: 30/700
# Training
# Epoch: 31/700
# Training
# Epoch: 32/700
# Training
# Epoch: 33/700
# Training
# Epoch: 34/700
# Training
# Epoch: 35/700
# Training
# Epoch: 36/700
# Training
# Epoch: 37/700
# Training
# Epoch: 38/700
# Training
# Epoch: 39/700
# Training
# Epoch: 40/700
# Training
# Epoch: 41/700
# Training
# Epoch: 42/700
# Training
# Epoch: 43/700
# Training
# Epoch: 44/700
# Training
# Epoch: 45/700
# Training
# Epoch: 46/700
# Training
# Epoch: 47/700
# Training
# Epoch: 48/700
# Training
# Epoch: 49/700
# Training
# Epoch: 50/700
# Training
# Epoch: 51/700
# Training
# Epoch: 52/700
# Training
# Epoch: 53/700
# Training
# Epoch: 54/700
# Training
# Epoch: 55/700
# Training
# Epoch: 56/700
# Training
# Epoch: 57/700
# Training
# Epoch: 58/700
# Training
# Epoch: 59/700
# Training
# Epoch: 60/700
# Training
# Epoch: 61/700
# Training
# Epoch: 62/700
# Training
# Epoch: 63/700
# Training
# Epoch: 64/700
# Training
# Epoch: 65/700
# Training
# Epoch: 66/700
# Training
# Epoch: 67/700
# Training
# Epoch: 68/700
# Training
# Epoch: 69/700
# Training
# Epoch: 70/700
# Training
# Epoch: 71/700
# Training
# Epoch: 72/700
# Training
# Epoch: 73/700
# Training
# Epoch: 74/700
# Training
# Epoch: 75/700
# Training
# Epoch: 76/700
# Training
# Epoch: 77/700
# Training
# Epoch: 78/700
# Training
# Epoch: 79/700
# Training
# Epoch: 80/700
# Training
# Epoch: 81/700
# Training
# Epoch: 82/700
# Training
# Epoch: 83/700
# Training
# Epoch: 84/700
# Training
# Epoch: 85/700
# Training
# Epoch: 86/700
# Training
# Epoch: 87/700
# Training
# Epoch: 88/700
# Training
# Epoch: 89/700
# Training
# Epoch: 90/700
# Training
# Epoch: 91/700
# Training
# Epoch: 92/700
# Training
# Epoch: 93/700
# Training
# Epoch: 94/700
# Training
# Epoch: 95/700
# Training
# Epoch: 96/700
# Training
# Epoch: 97/700
# Training
# Epoch: 98/700
# Training
# Epoch: 99/700
# Training
# Epoch: 100/700
# Train error 416
# vallidation
# Validation 157
# Training
# Epoch: 101/700
# Training
# Epoch: 102/700
# Training
# Epoch: 103/700
# Training
# Epoch: 104/700
# Training
# Epoch: 105/700
# Training
# Epoch: 106/700
# Training
# Epoch: 107/700
# Training
# Epoch: 108/700
# Training
# Epoch: 109/700
# Training
# Epoch: 110/700
# Training
# Epoch: 111/700
# Training
# Epoch: 112/700
# Training
# Epoch: 113/700
# Training
# Epoch: 114/700
# Training
# Epoch: 115/700
# Training
# Epoch: 116/700
# Training
# Epoch: 117/700
# Training
# Epoch: 118/700
# Training
# Epoch: 119/700
# Training
# Epoch: 120/700
# Training
# Epoch: 121/700
# Training
# Epoch: 122/700
# Training
# Epoch: 123/700
# Training
# Epoch: 124/700
# Training
# Epoch: 125/700
# Training
# Epoch: 126/700
# Training
# Epoch: 127/700
# Training
# Epoch: 128/700
# Training
# Epoch: 129/700
# Training
# Epoch: 130/700
# Training
# Epoch: 131/700
# Training
# Epoch: 132/700
# Training
# Epoch: 133/700
# Training
# Epoch: 134/700
# Training
# Epoch: 135/700
# Training
# Epoch: 136/700
# Training
# Epoch: 137/700
# Training
# Epoch: 138/700
# Training
# Epoch: 139/700
# Training
# Epoch: 140/700
# Training
# Epoch: 141/700
# Training
# Epoch: 142/700
# Training
# Epoch: 143/700
# Training
# Epoch: 144/700
# Training
# Epoch: 145/700
# Training
# Epoch: 146/700
# Training
# Epoch: 147/700
# Training
# Epoch: 148/700
# Training
# Epoch: 149/700
# Training
# Epoch: 150/700
# Training
# Epoch: 151/700
# Training
# Epoch: 152/700
# Training
# Epoch: 153/700
# Training
# Epoch: 154/700
# Training
# Epoch: 155/700
# Training
# Epoch: 156/700
# Training
# Epoch: 157/700
# Training
# Epoch: 158/700
# Training
# Epoch: 159/700
# Training
# Epoch: 160/700
# Training
# Epoch: 161/700
# Training
# Epoch: 162/700
# Training
# Epoch: 163/700
# Training
# Epoch: 164/700
# Training
# Epoch: 165/700
# Training
# Epoch: 166/700
# Training
# Epoch: 167/700
# Training
# Epoch: 168/700
# Training
# Epoch: 169/700
# Training
# Epoch: 170/700
# Training
# Epoch: 171/700
# Training
# Epoch: 172/700
# Training
# Epoch: 173/700
# Training
# Epoch: 174/700
# Training
# Epoch: 175/700
# Training
# Epoch: 176/700
# Training
# Epoch: 177/700
# Training
# Epoch: 178/700
# Training
# Epoch: 179/700
# Training
# Epoch: 180/700
# Training
# Epoch: 181/700
# Training
# Epoch: 182/700
# Training
# Epoch: 183/700
# Training
# Epoch: 184/700
# Training
# Epoch: 185/700
# Training
# Epoch: 186/700
# Training
# Epoch: 187/700
# Training
# Epoch: 188/700
# Training
# Epoch: 189/700
# Training
# Epoch: 190/700
# Training
# Epoch: 191/700
# Training
# Epoch: 192/700
# Training
# Epoch: 193/700
# Training
# Epoch: 194/700
# Training
# Epoch: 195/700
# Training
# Epoch: 196/700
# Training
# Epoch: 197/700
# Training
# Epoch: 198/700
# Training
# Epoch: 199/700
# Training
# Epoch: 200/700
# Train error 185
# vallidation
# Validation 194
# Training
# Epoch: 201/700
# Training
# Epoch: 202/700
# Training
# Epoch: 203/700
# Training
# Epoch: 204/700
# Training
# Epoch: 205/700
# Training
# Epoch: 206/700
# Training
# Epoch: 207/700
# Training
# Epoch: 208/700
# Training
# Epoch: 209/700
# Training
# Epoch: 210/700
# Training
# Epoch: 211/700
# Training
# Epoch: 212/700
# Training
# Epoch: 213/700
# Training
# Epoch: 214/700
# Training
# Epoch: 215/700
# Training
# Epoch: 216/700
# Training
# Epoch: 217/700
# Training
# Epoch: 218/700
# Training
# Epoch: 219/700
# Training
# Epoch: 220/700
# Training
# Epoch: 221/700
# Training
# Epoch: 222/700
# Training
# Epoch: 223/700
# Training
# Epoch: 224/700
# Training
# Epoch: 225/700
# Training
# Epoch: 226/700
# Training
# Epoch: 227/700
# Training
# Epoch: 228/700
# Training
# Epoch: 229/700
# Training
# Epoch: 230/700
# Training
# Epoch: 231/700
# Training
# Epoch: 232/700
# Training
# Epoch: 233/700
# Training
# Epoch: 234/700
# Training
# Epoch: 235/700
# Training
# Epoch: 236/700
# Training
# Epoch: 237/700
# Training
# Epoch: 238/700
# Training
# Epoch: 239/700
# Training
# Epoch: 240/700
# Training
# Epoch: 241/700
# Training
# Epoch: 242/700
# Training
# Epoch: 243/700
# Training
# Epoch: 244/700
# Training
# Epoch: 245/700
# Training
# Epoch: 246/700
# Training
# Epoch: 247/700
# Training
# Epoch: 248/700
# Training
# Epoch: 249/700
# Training
# Epoch: 250/700
# Training
# Epoch: 251/700
# Training
# Epoch: 252/700
# Training
# Epoch: 253/700
# Training
# Epoch: 254/700
# Training
# Epoch: 255/700
# Training
# Epoch: 256/700
# Training
# Epoch: 257/700
# Training
# Epoch: 258/700
# Training
# Epoch: 259/700
# Training
# Epoch: 260/700
# Training
# Epoch: 261/700
# Training
# Epoch: 262/700
# Training
# Epoch: 263/700
# Training
# Epoch: 264/700
# Training
# Epoch: 265/700
# Training
# Epoch: 266/700
# Training
# Epoch: 267/700
# Training
# Epoch: 268/700
# Training
# Epoch: 269/700
# Training
# Epoch: 270/700
# Training
# Epoch: 271/700
# Training
# Epoch: 272/700
# Training
# Epoch: 273/700
# Training
# Epoch: 274/700
# Training
# Epoch: 275/700
# Training
# Epoch: 276/700
# Training
# Epoch: 277/700
# Training
# Epoch: 278/700
# Training
# Epoch: 279/700
# Training
# Epoch: 280/700
# Training
# Epoch: 281/700
# Training
# Epoch: 282/700
# Training
# Epoch: 283/700
# Training
# Epoch: 284/700
# Training
# Epoch: 285/700
# Training
# Epoch: 286/700
# Training
# Epoch: 287/700
# Training
# Epoch: 288/700
# Training
# Epoch: 289/700
# Training
# Epoch: 290/700
# Training
# Epoch: 291/700
# Training
# Epoch: 292/700
# Training
# Epoch: 293/700
# Training
# Epoch: 294/700
# Training
# Epoch: 295/700
# Training
# Epoch: 296/700
# Training
# Epoch: 297/700
# Training
# Epoch: 298/700
# Training
# Epoch: 299/700
# Training
# Epoch: 300/700
# Train error 94
# vallidation
# Validation 225
# Training
# Epoch: 301/700
# Training
# Epoch: 302/700
# Training
# Epoch: 303/700
# Training
# Epoch: 304/700
# Training
# Epoch: 305/700
# Training
# Epoch: 306/700
# Training
# Epoch: 307/700
# Training
# Epoch: 308/700
# Training
# Epoch: 309/700
# Training
# Epoch: 310/700
# Training
# Epoch: 311/700
# Training
# Epoch: 312/700
# Training
# Epoch: 313/700
# Training
# Epoch: 314/700
# Training
# Epoch: 315/700
# Training
# Epoch: 316/700
# Training
# Epoch: 317/700
# Training
# Epoch: 318/700
# Training
# Epoch: 319/700
# Training
# Epoch: 320/700
# Training
# Epoch: 321/700
# Training
# Epoch: 322/700
# Training
# Epoch: 323/700
# Training
# Epoch: 324/700
# Training
# Epoch: 325/700
# Training
# Epoch: 326/700
# Training
# Epoch: 327/700
# Training
# Epoch: 328/700
# Training
# Epoch: 329/700
# Training
# Epoch: 330/700
# Training
# Epoch: 331/700
# Training
# Epoch: 332/700
# Training
# Epoch: 333/700
# Training
# Epoch: 334/700
# Training
# Epoch: 335/700
# Training
# Epoch: 336/700
# Training
# Epoch: 337/700
# Training
# Epoch: 338/700
# Training
# Epoch: 339/700
# Training
# Epoch: 340/700
# Training
# Epoch: 341/700
# Training
# Epoch: 342/700
# Training
# Epoch: 343/700
# Training
# Epoch: 344/700
# Training
# Epoch: 345/700
# Training
# Epoch: 346/700
# Training
# Epoch: 347/700
# Training
# Epoch: 348/700
# Training
# Epoch: 349/700
# Training
# Epoch: 350/700
# Training
# Epoch: 351/700
# Training
# Epoch: 352/700
# Training
# Epoch: 353/700
# Training
# Epoch: 354/700
# Training
# Epoch: 355/700
# Training
# Epoch: 356/700
# Training
# Epoch: 357/700
# Training
# Epoch: 358/700
# Training
# Epoch: 359/700
# Training
# Epoch: 360/700
# Training
# Epoch: 361/700
# Training
# Epoch: 362/700
# Training
# Epoch: 363/700
# Training
# Epoch: 364/700
# Training
# Epoch: 365/700
# Training
# Epoch: 366/700
# Training
# Epoch: 367/700
# Training
# Epoch: 368/700
# Training
# Epoch: 369/700
# Training
# Epoch: 370/700
# Training
# Epoch: 371/700
# Training
# Epoch: 372/700
# Training
# Epoch: 373/700
# Training
# Epoch: 374/700
# Training
# Epoch: 375/700
# Training
# Epoch: 376/700
# Training
# Epoch: 377/700
# Training
# Epoch: 378/700
# Training
# Epoch: 379/700
# Training
# Epoch: 380/700
# Training
# Epoch: 381/700
# Training
# Epoch: 382/700
# Training
# Epoch: 383/700
# Training
# Epoch: 384/700
# Training
# Epoch: 385/700
# Training
# Epoch: 386/700
# Training
# Epoch: 387/700
# Training
# Epoch: 388/700
# Training
# Epoch: 389/700
# Training
# Epoch: 390/700
# Training
# Epoch: 391/700
# Training
# Epoch: 392/700
# Training
# Epoch: 393/700
# Training
# Epoch: 394/700
# Training
# Epoch: 395/700
# Training
# Epoch: 396/700
# Training
# Epoch: 397/700
# Training
# Epoch: 398/700
# Training
# Epoch: 399/700
# Training
# Epoch: 400/700
# Train error 60
# vallidation
# Validation 241
# Training
# Epoch: 401/700
# Training
# Epoch: 402/700
# Training
# Epoch: 403/700
# Training
# Epoch: 404/700
# Training
# Epoch: 405/700
# Training
# Epoch: 406/700
# Training
# Epoch: 407/700
# Training
# Epoch: 408/700
# Training
# Epoch: 409/700
# Training
# Epoch: 410/700
# Training
# Epoch: 411/700
# Training
# Epoch: 412/700
# Training
# Epoch: 413/700
# Training
# Epoch: 414/700
# Training
# Epoch: 415/700
# Training
# Epoch: 416/700
# Training
# Epoch: 417/700
# Training
# Epoch: 418/700
# Training
# Epoch: 419/700
# Training
# Epoch: 420/700
# Training
# Epoch: 421/700
# Training
# Epoch: 422/700
# Training
# Epoch: 423/700
# Training
# Epoch: 424/700
# Training
# Epoch: 425/700
# Training
# Epoch: 426/700
# Training
# Epoch: 427/700
# Training
# Epoch: 428/700
# Training
# Epoch: 429/700
# Training
# Epoch: 430/700
# Training
# Epoch: 431/700
# Training
# Epoch: 432/700
# Training
# Epoch: 433/700
# Training
# Epoch: 434/700
# Training
# Epoch: 435/700
# Training
# Epoch: 436/700
# Training
# Epoch: 437/700
# Training
# Epoch: 438/700
# Training
# Epoch: 439/700
# Training
# Epoch: 440/700
# Training
# Epoch: 441/700
# Training
# Epoch: 442/700
# Training
# Epoch: 443/700
# Training
# Epoch: 444/700
# Training
# Epoch: 445/700
# Training
# Epoch: 446/700
# Training
# Epoch: 447/700
# Training
# Epoch: 448/700
# Training
# Epoch: 449/700
# Training
# Epoch: 450/700
# Training
# Epoch: 451/700
# Training
# Epoch: 452/700
# Training
# Epoch: 453/700
# Training
# Epoch: 454/700
# Training
# Epoch: 455/700
# Training
# Epoch: 456/700
# Training
# Epoch: 457/700
# Training
# Epoch: 458/700
# Training
# Epoch: 459/700
# Training
# Epoch: 460/700
# Training
# Epoch: 461/700
# Training
# Epoch: 462/700
# Training
# Epoch: 463/700
# Training
# Epoch: 464/700
# Training
# Epoch: 465/700
# Training
# Epoch: 466/700
# Training
# Epoch: 467/700
# Training
# Epoch: 468/700
# Training
# Epoch: 469/700
# Training
# Epoch: 470/700
# Training
# Epoch: 471/700
# Training
# Epoch: 472/700
# Training
# Epoch: 473/700
# Training
# Epoch: 474/700
# Training
# Epoch: 475/700
# Training
# Epoch: 476/700
# Training
# Epoch: 477/700
# Training
# Epoch: 478/700
# Training
# Epoch: 479/700
# Training
# Epoch: 480/700
# Training
# Epoch: 481/700
# Training
# Epoch: 482/700
# Training
# Epoch: 483/700
# Training
# Epoch: 484/700
# Training
# Epoch: 485/700
# Training
# Epoch: 486/700
# Training
# Epoch: 487/700
# Training
# Epoch: 488/700
# Training
# Epoch: 489/700
# Training
# Epoch: 490/700
# Training
# Epoch: 491/700
# Training
# Epoch: 492/700
# Training
# Epoch: 493/700
# Training
# Epoch: 494/700
# Training
# Epoch: 495/700
# Training
# Epoch: 496/700
# Training
# Epoch: 497/700
# Training
# Epoch: 498/700
# Training
# Epoch: 499/700
# Training
# Epoch: 500/700
# Train error 47
# vallidation
# Validation 251
# Training
# Epoch: 501/700
# Training
# Epoch: 502/700
# Training
# Epoch: 503/700
# Training
# Epoch: 504/700
# Training
# Epoch: 505/700
# Training
# Epoch: 506/700
# Training
# Epoch: 507/700
# Training
# Epoch: 508/700
# Training
# Epoch: 509/700
# Training
# Epoch: 510/700
# Training
# Epoch: 511/700
# Training
# Epoch: 512/700
# Training
# Epoch: 513/700
# Training
# Epoch: 514/700
# Training
# Epoch: 515/700
# Training
# Epoch: 516/700
# Training
# Epoch: 517/700
# Training
# Epoch: 518/700
# Training
# Epoch: 519/700
# Training
# Epoch: 520/700
# Training
# Epoch: 521/700
# Training
# Epoch: 522/700
# Training
# Epoch: 523/700
# Training
# Epoch: 524/700
# Training
# Epoch: 525/700
# Training
# Epoch: 526/700
# Training
# Epoch: 527/700
# Training
# Epoch: 528/700
# Training
# Epoch: 529/700
# Training
# Epoch: 530/700
# Training
# Epoch: 531/700
# Training
# Epoch: 532/700
# Training
# Epoch: 533/700
# Training
# Epoch: 534/700
# Training
# Epoch: 535/700
# Training
# Epoch: 536/700
# Training
# Epoch: 537/700
# Training
# Epoch: 538/700
# Training
# Epoch: 539/700
# Training
# Epoch: 540/700
# Training
# Epoch: 541/700
# Training
# Epoch: 542/700
# Training
# Epoch: 543/700
# Training
# Epoch: 544/700
# Training
# Epoch: 545/700
# Training
# Epoch: 546/700
# Training
# Epoch: 547/700
# Training
# Epoch: 548/700
# Training
# Epoch: 549/700
# Training
# Epoch: 550/700
# Training
# Epoch: 551/700
# Training
# Epoch: 552/700
# Training
# Epoch: 553/700
# Training
# Epoch: 554/700
# Training
# Epoch: 555/700
# Training
# Epoch: 556/700
# Training
# Epoch: 557/700
# Training
# Epoch: 558/700
# Training
# Epoch: 559/700
# Training
# Epoch: 560/700
# Training
# Epoch: 561/700
# Training
# Epoch: 562/700
# Training
# Epoch: 563/700
# Training
# Epoch: 564/700
# Training
# Epoch: 565/700
# Training
# Epoch: 566/700
# Training
# Epoch: 567/700
# Training
# Epoch: 568/700
# Training
# Epoch: 569/700
# Training
# Epoch: 570/700
# Training
# Epoch: 571/700
# Training
# Epoch: 572/700
# Training
# Epoch: 573/700
# Training
# Epoch: 574/700
# Training
# Epoch: 575/700
# Training
# Epoch: 576/700
# Training
# Epoch: 577/700
# Training
# Epoch: 578/700
# Training
# Epoch: 579/700
# Training
# Epoch: 580/700
# Training
# Epoch: 581/700
# Training
# Epoch: 582/700
# Training
# Epoch: 583/700
# Training
# Epoch: 584/700
# Training
# Epoch: 585/700
# Training
# Epoch: 586/700
# Training
# Epoch: 587/700
# Training
# Epoch: 588/700
# Training
# Epoch: 589/700
# Training
# Epoch: 590/700
# Training
# Epoch: 591/700
# Training
# Epoch: 592/700
# Training
# Epoch: 593/700
# Training
# Epoch: 594/700
# Training
# Epoch: 595/700
# Training
# Epoch: 596/700
# Training
# Epoch: 597/700
# Training
# Epoch: 598/700
# Training
# Epoch: 599/700
# Training
# Epoch: 600/700
# Train error 41
# vallidation
# Validation 257
# Training
# Epoch: 601/700
# Training
# Epoch: 602/700
# Training
# Epoch: 603/700
# Training
# Epoch: 604/700
# Training
# Epoch: 605/700
# Training
# Epoch: 606/700
# Training
# Epoch: 607/700
# Training
# Epoch: 608/700
# Training
# Epoch: 609/700
# Training
# Epoch: 610/700
# Training
# Epoch: 611/700
# Training
# Epoch: 612/700
# Training
# Epoch: 613/700
# Training
# Epoch: 614/700
# Training
# Epoch: 615/700
# Training
# Epoch: 616/700
# Training
# Epoch: 617/700
# Training
# Epoch: 618/700
# Training
# Epoch: 619/700
# Training
# Epoch: 620/700
# Training
# Epoch: 621/700
# Training
# Epoch: 622/700
# Training
# Epoch: 623/700
# Training
# Epoch: 624/700
# Training
# Epoch: 625/700
# Training
# Epoch: 626/700
# Training
# Epoch: 627/700
# Training
# Epoch: 628/700
# Training
# Epoch: 629/700
# Training
# Epoch: 630/700
# Training
# Epoch: 631/700
# Training
# Epoch: 632/700
# Training
# Epoch: 633/700
# Training
# Epoch: 634/700
# Training
# Epoch: 635/700
# Training
# Epoch: 636/700
# Training
# Epoch: 637/700
# Training
# Epoch: 638/700
# Training
# Epoch: 639/700
# Training
# Epoch: 640/700
# Training
# Epoch: 641/700
# Training
# Epoch: 642/700
# Training
# Epoch: 643/700
# Training
# Epoch: 644/700
# Training
# Epoch: 645/700
# Training
# Epoch: 646/700
# Training
# Epoch: 647/700
# Training
# Epoch: 648/700
# Training
# Epoch: 649/700
# Training
# Epoch: 650/700
# Training
# Epoch: 651/700
# Training
# Epoch: 652/700
# Training
# Epoch: 653/700
# Training
# Epoch: 654/700
# Training
# Epoch: 655/700
# Training
# Epoch: 656/700
# Training
# Epoch: 657/700
# Training
# Epoch: 658/700
# Training
# Epoch: 659/700
# Training
# Epoch: 660/700
# Training
# Epoch: 661/700
# Training
# Epoch: 662/700
# Training
# Epoch: 663/700
# Training
# Epoch: 664/700
# Training
# Epoch: 665/700
# Training
# Epoch: 666/700
# Training
# Epoch: 667/700
# Training
# Epoch: 668/700
# Training
# Epoch: 669/700
# Training
# Epoch: 670/700
# Training
# Epoch: 671/700
# Training
# Epoch: 672/700
# Training
# Epoch: 673/700
# Training
# Epoch: 674/700
# Training
# Epoch: 675/700
# Training
# Epoch: 676/700
# Training
# Epoch: 677/700
# Training
# Epoch: 678/700
# Training
# Epoch: 679/700
# Training
# Epoch: 680/700
# Training
# Epoch: 681/700
# Training
# Epoch: 682/700
# Training
# Epoch: 683/700
# Training
# Epoch: 684/700
# Training
# Epoch: 685/700
# Training
# Epoch: 686/700
# Training
# Epoch: 687/700
# Training
# Epoch: 688/700
# Training
# Epoch: 689/700
# Training
# Epoch: 690/700
# Training
# Epoch: 691/700
# Training
# Epoch: 692/700
# Training
# Epoch: 693/700
# Training
# Epoch: 694/700
# Training
# Epoch: 695/700
# Training
# Epoch: 696/700
# Training
# Epoch: 697/700
# Training
# Epoch: 698/700
# Training
# Epoch: 699/700
# Training
# Epoch: 700/700
# Train error 38
# vallidation
# Validation 260
# (<__main__.MLP at 0x284a84cf080>,
#  [416.7050625429607,
#   185.06996870149925,
#   94.65148048821331,
#   60.133167814430266,
#   47.268759929015694,
#   41.391252085080986,
#   38.57092035484732],
#  [157.0832363100371,
#   194.3271267650353,
#   225.27980544102923,
#   241.94639625591623,
#   251.8414979943842,
#   257.1222027834722,
#   260.1135956827792])

# %%
fig, axes = plt.subplots()
plt.ylabel('Error')
plt.xlabel('100th iterations')
axes.plot(nn1.test_err, label = 'Validation Error')
axes.plot(nn1.train_err, label = 'Training Error')
plt.tight_layout()
axes.legend(loc='upper right', frameon=False)


#TODO: Plots for training and test errors for the 2 models

# %%
fig, axes = plt.subplots()
plt.ylabel('Error')
plt.xlabel('100th iterations')
axes.plot(nn2.test_err, label = 'Validation Error')
axes.plot(nn2.train_err, label = 'Training Error')
plt.tight_layout()
axes.legend(loc='upper right', frameon=False)


#TODO: Plots for training and test errors for the 2 models

# %% [markdown]
# ---
# **Points:** $0.0$ of $3.0$
# **Comments:** None
#
# ---

# %% [markdown]
# c) Using these plots, make suggestions for an early stopping criteria for each hidden layer size. (1 point)
#
# Answer: When using 50 neurons for the hidden layer, we could stop the training. . When using 200 neurons, after ..
#
# d) As the number of neurons are increased, you will observe differences in the early stopping criteria for each hidden layer size. Why do you observe such differences? (1 point)
#
# Answer: When the number of neurons is increased, the model learns faster and, consequently, overfits earlier. Therefore, the training process must be stopped earlier.
#
# e) How early stopping can be similar to L2 regularization? (1 point)
#
# Answer: Both early stopping and L2 regularization try to find parameter values which minimize the cost and, at the same time, lay near to the origin.

# %% [markdown]
# ---
# **Points:** $0.0$ of $3.0$
# **Comments:** None
#
# ---

# %% [markdown]
# ## 3. Data Augmentation$~$ (12 points)

# %% [markdown]
# While the performance of neural networks can significantly increase with increasing training data size, collecting a large dataset is hard and needs a lot of work in annotation. Therefore, data augmentation is a widley used technique in machine learning to artificially increase your training set size. In case of images, data augmentation methods can be scaling, rotations, cropping, or mirroring. In this exercise, we will get familiar with some of these techniques and apply them on the MNIST fashion dataset.
#
# For additional reading, you can refer to the following paper (also known as AlexNet) which is one of the papers that revolutionized neural networks applications in image classification and has used data augmentation to increase training data size:
#
# Krizhevsky, Alex, Ilya Sutskever, and Geoffrey E. Hinton. "Imagenet classification with deep convolutional neural networks." Advances in neural information processing systems. 2012 (http://papers.nips.cc/paper/4824-imagenet-classification-with-deep-convolutional-neural-networks.pdf).
#
# **Additional note:** These types of augmentation methods usually work best with a type of neural networks called *Convolutional Neural Networks (CNNs)* becuase these networks can learn features that are invariant under transformations (Wikipedia: https://en.wikipedia.org/wiki/Convolutional_neural_network). However, we will use it here with a simple fully connected network to learn the concept.

# %% [markdown]
# Note: for all the next questions, the argument of the function is a 2d Numpy array of 28x28 (one single MNIST example before reshaping)
#
# a) One common way of data augmentation in images is flipping, here, we will flip the images across the vertical axis. In the following, implement a function that takes an input image and perform vertical flipping. Call your function with a simple  input image and display both the original and transformed images. (0.5 point)

# %%
#TODO: Implement vertical flipping. Use Numpy
def flip_img(one_input_image):
    flipped_image = np.flip(one_input_image,1)
    fig, ax = plt.subplots(1, 2)
    ax[0].imshow(one_input_image)
    ax[1].imshow(flipped_image)
    return flipped_image

# %%
from skimage import data
flip_img(data.astronaut())
# Out:
# array([[[125, 119, 110],
#         [120, 117, 106],
#         [127, 120, 115],
#         ...,
#         [ 63,  58, 102],
#         [109, 103, 124],
#         [154, 147, 151]],
#
#        [[121, 116, 105],
#         [124, 115, 108],
#         [127, 118, 112],
#         ...,
#         [113, 114, 124],
#         [144, 141, 143],
#         [177, 171, 171]],
#
#        [[124, 114, 109],
#         [126, 116, 112],
#         [128, 120, 117],
#         ...,
#         [168, 165, 164],
#         [182, 178, 175],
#         [201, 194, 193]],
#
#        ...,
#
#        [[  0,   0,   0],
#         [  0,   0,   1],
#         [  0,   0,   0],
#         ...,
#         [183, 168, 170],
#         [186, 170, 177],
#         [186, 170, 176]],
#
#        [[  0,   0,   0],
#         [  1,   1,   1],
#         [  0,   0,   1],
#         ...,
#         [185, 164, 176],
#         [182, 167, 171],
#         [183, 169, 170]],
#
#        [[  0,   0,   0],
#         [  1,   1,   1],
#         [  0,   0,   0],
#         ...,
#         [180, 162, 171],
#         [183, 165, 169],
#         [184, 167, 172]]], dtype=uint8)

# %% [markdown]
# b) Another common way is image rotation, here, we will flip the images 90 degrees clock wise. In the following, implement a function that takes a one input image and perform rotation. Call your function with a simple one input image and display both the original and transformed images (0.5 point).

# %%
#TODO: Implement image rotation by 90 degrees clockwise using Numpy
def rotate_img(one_input_image):
    rotated_img = np.rot90(one_input_image,3)
    fig, ax = plt.subplots(1, 2)
    ax[0].imshow(one_input_image)
    ax[1].imshow(rotated_img)
    return rotated_img

# %%
rotate_img(data.astronaut())
# Out:
# array([[[184, 167, 172],
#         [183, 169, 170],
#         [186, 170, 176],
#         ...,
#         [201, 194, 193],
#         [177, 171, 171],
#         [154, 147, 151]],
#
#        [[183, 165, 169],
#         [182, 167, 171],
#         [186, 170, 177],
#         ...,
#         [182, 178, 175],
#         [144, 141, 143],
#         [109, 103, 124]],
#
#        [[180, 162, 171],
#         [185, 164, 176],
#         [183, 168, 170],
#         ...,
#         [168, 165, 164],
#         [113, 114, 124],
#         [ 63,  58, 102]],
#
#        ...,
#
#        [[  0,   0,   0],
#         [  0,   0,   1],
#         [  0,   0,   0],
#         ...,
#         [128, 120, 117],
#         [127, 118, 112],
#         [127, 120, 115]],
#
#        [[  1,   1,   1],
#         [  1,   1,   1],
#         [  0,   0,   1],
#         ...,
#         [126, 116, 112],
#         [124, 115, 108],
#         [120, 117, 106]],
#
#        [[  0,   0,   0],
#         [  0,   0,   0],
#         [  0,   0,   0],
#         ...,
#         [124, 114, 109],
#         [121, 116, 105],
#         [125, 119, 110]]], dtype=uint8)

# %% [markdown]
# c) Perform a function that scales one image by a given scale ratio (>1 to work as a zoom-out), make sure that the scaled image has the same size. Call your function with a simple one input image and a scale ratio of 2, and display both the original and transformed images (0.5).

# %%
#TODO: Implement image scaling
#For this, you can use an image processing library such as: https://scikit-image.org/ (install if needed)
from scipy.ndimage import zoom
def scale_img(one_input_image, scale_ratio):
    h,w = one_input_image.shape[:2]
    zoomed_h = int(np.round(h * zoom_factor))
    zoomed_w = int(np.round(w * zoom_factor))
    top = (h - zoomed_h) // 2
    left = (w - zoomed_w) // 2
    fig, ax = plt.subplots(1, 2)
    ax[0].imshow(one_input_image)
    ax[1].imshow(scaled_img)
    return scaled_img

# %%
scale_img(data.astronaut,2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-6cd182ac99bd> in <module>
# ----> 1 scale_img(data.astronaut,2)
#
# <ipython-input-27-03c668be80cd> in scale_img(one_input_image, scale_ratio)
#       3 from scipy.ndimage import zoom
#       4 def scale_img(one_input_image, scale_ratio):
# ----> 5     h, w = one_input_image.shape[:2]
#       6     zoom_tuple = (zoom_factor,) * 2 + (1,) * (img.ndim - 2)
#       7     zh = int(np.round(h * zoom_factor))
#
# AttributeError: 'function' object has no attribute 'shape'

# %% [markdown]
# d) Another used method is translation, here, we want to translate our image to the right or the left only, make sure to do zero padding as needed after the translation. Call your function twice, once with a simple one input image and a translation of 5 pixels to the right, and once with the same input image but with a translation of 5 pixels to the left (1 point).

# %%
#TODO: Implement image translation. Use Numpy
def translate_img(one_input_image, right_or_left_flag, shift_pixels):
    return translated_img

# %% [markdown]
# e) Another way of augmentation is introducing random noise to your training set. Implement a function that takes an input image and adds Gaussian noise of mean 0 and std 0.2 to the original image (0.5 points).

# %%
#TODO: Implement adding Gaussian noise. Use Numpy
def distort_img(one_input_image):
    return distorted_img

# %% [markdown]
# f) What are other advantages of data augmentation beside increasing data size? Elaborate on in which cases each type of data augmentation mentioned above could be effective (scaling, translation, etc.) (1.5 point)
#
# Answer:

# %% [markdown]
# g) There are two ways of performing data augmentation. One is offline augmentation where we apply these augmentations before the training and increase the training set size by a factor (that is usually done for small datasets), another way is to apply these augmentations for each mini-batch online during the training (used for larger datasets). We will use here online augmentation in order to not extensively increase the required computation time.
#
# 1. Perform a function that takes an input of mini-batch images, and for each image in these images, decide if to perform augmentation or not based on a random flip.
#
# 2. If augmentation is performed, decide which type of augmentation to use based on another random variable (options: flip, scale, rotate, translate, Gaussian distortion).
#
# 3. For scaling, generate a random scaling factor (in range from 1 to 2).
#
# 4. For translation, decide randomly based on another variable if translation is done to left or right, and generate a random transition between 5 and 10 pixels.
#
# Note that the number of observation in the batch will be the same.
#
# (3.5 points)

# %%
#TODO: Implement online_augmentation
def online_augmentation(batch_images):
    return augmented_batch

# %% [markdown]
# h) Now use the function (online_augmentation) that you implemented in 7, to edit the (fit) function in the class in Task 1.
#
# Note: Use the same X_trainval, Y_trainval, X_test, Y_test from task 1. However, **reshape** the mini-batches to a 2d image shape before applying augmentation and after that reshape it again to the flatted version. The fit function has data_augmentation parameter (default: False), if true, data augmentation should be performed (without early stopping and dropout).
#
# (1 point)

# %% [markdown]
# i) Create an instance of the MLP class with 50 neurons. Run the train function for 1500 epochs. Plot the train and test performance over epochs (1.5 point).

# %%
#TODO: create an instrance of the class
#TODO: run the fit function
#TODO: Plot the train and test performance over epochs

# %% [markdown]
# j) Compare the performance of this version of the network with the vanilla-network that you have created in Task 2 (the early stopping without dropout). Do you see any performance increase. Explain why or why not. Based on this dataset, what form of data augmentation you think would be less effective than the others? (1.5 point)

# %% [markdown]
# ---
# **Points:** $0.0$ of $12.0$
# **Comments:** None

# %% [markdown]
# ---

# %% [markdown]
# ## Submission instructions
# You should provide a single Jupyter notebook (.ipynb file) as the solution. Put the names and student ids of your team members below. **Make sure to submit only 1 solution to only 1 tutor.**
#
# - Jane Doe, 123456
# - Jane Doe, 123456
# - Jane Doe, 123456

# %% [markdown]
# ## Points: 0.0 of 30.0 points
